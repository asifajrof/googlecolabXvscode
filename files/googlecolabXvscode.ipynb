# %% [markdown]
# <a href="https://colab.research.google.com/github/asifajrof/googlecolabXvscode/blob/main/files/googlecolabXvscode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # googlecolabXvscode
#
# using vscode in google colab

# %% [markdown]
# ## installation

# %% [markdown]
# we need [`colabcode`](https://github.com/abhishekkrthakur/colabcode), but as of now, google colaboratory does not support the use of it. you will see a warning if you want to install `colabcode`.
#
# ![colab-warning.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ### the workaround
#
# put the install command in a [file](https://github.com/asifajrof/googlecolabXvscode/blob/main/files/install-colabcode), run that file from colab. apparently they are dumb like that.

# %%
# !wget "https://raw.githubusercontent.com/asifajrof/googlecolabXvscode/main/files/install-colabcode"
# !bash install-colabcode
# Out:
# --2023-03-08 12:02:08--  https://raw.githubusercontent.com/asifajrof/googlecolabXvscode/main/files/install-colabcode
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30 [text/plain]
# Saving to: ‘install-colabcode’
#
# install-colabcode   100%[===================>]      30  --.-KB/s    in 0s
#
# 2023-03-08 12:02:08 (2.18 MB/s) - ‘install-colabcode’ saved [30/30]
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 761.3/761.3 KB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 63.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 KB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 72.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.4/347.4 KB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 KB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 KB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 KB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 77.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 76.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 73.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 72.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 71.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 81.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 76.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.8 MB/s eta 0:00:00
#   Building wheel for pyngrok (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 2.2.3 requires click>=8.0, but you have click 7.1.2 which is incompatible.

# %% [markdown]
# ## ngrok setup

# %% [markdown]
# ### signup
#
# register an account at [ngrok](https://ngrok.com/signup).

# %% [markdown]
# ### get authtoken
#
# after signing up, get your authtoken from [your dashboard](https://dashboard.ngrok.com/get-started/your-authtoken).

# %% [markdown]
# ### setup config
#
# put your authtoken in [`ngrok.yml`](https://github.com/asifajrof/googlecolabXvscode/blob/main/files/ngrok.yml) file.

# %%
# !wget "https://raw.githubusercontent.com/asifajrof/googlecolabXvscode/main/files/ngrok.yml"
# Out:
# --2023-03-08 12:02:25--  https://raw.githubusercontent.com/asifajrof/googlecolabXvscode/main/files/ngrok.yml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 74 [text/plain]
# Saving to: ‘ngrok.yml’
#
# ngrok.yml           100%[===================>]      74  --.-KB/s    in 0s
#
# 2023-03-08 12:02:25 (5.24 MB/s) - ‘ngrok.yml’ saved [74/74]

# %%
# !mkdir -p ~/.ngrok2/
# !mv ngrok.yml ~/.ngrok2/ngrok.yml

# %% [markdown]
# ## run vscode in google colaboratory

# %%
from colabcode import ColabCode
ColabCode(port=1234, password="googlecolabXvscode", mount_drive=True)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://cc83-34-173-1-74.ngrok.io" -> "http://localhost:1234"
# Mounted at /content/drive
# [2023-03-08T12:03:31.668Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2023-03-08T12:03:31.669Z] info  Using user-data-dir ~/.local/share/code-server
# [2023-03-08T12:03:31.689Z] info  Using config file ~/.config/code-server/config.yaml
# [2023-03-08T12:03:31.689Z] info  HTTP server listening on http://127.0.0.1:1234
# [2023-03-08T12:03:31.689Z] info    - Authentication is enabled
# [2023-03-08T12:03:31.689Z] info      - Using password from $PASSWORD
# [2023-03-08T12:03:31.689Z] info    - Not serving HTTPS
